# %%
import torch
print(torch.cuda.is_available()) # Should return True
print(torch.cuda.get_device_name(0)) # Shows your GPU name
# Out:
# True
# Quadro T1000

# %%
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.8444, 0.7459, 0.7727],
#         [0.3509, 0.5724, 0.4480],
#         [0.6005, 0.2543, 0.6035],
#         [0.6449, 0.3020, 0.5552],
#         [0.8457, 0.8618, 0.8893]])
